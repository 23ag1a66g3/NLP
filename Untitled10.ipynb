# %% [markdown]
# <a href="https://colab.research.google.com/github/23ag1a66g3/NLP/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# STEMMING

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import PorterStemmer as porterstemmer
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
text="hello world  "
stemmer=porterstemmer()
words=word_tokenize(text)
stemmed_words=[stemmer.stem(word) for word in words]
print(stemmed_words)
# Out:
# ['hello', 'world']

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %% [markdown]
# PARTS OF SPEECH TAGGING

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
from nltk import word_tokenize, pos_tag
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.

# %%
text = "ace engineering college"
tokens = word_tokenize(text)
tags = pos_tag(tokens)
print(tags)
# Out:
# [('ace', 'NN'), ('engineering', 'NN'), ('college', 'NN')]

# %% [markdown]
# ANALYSIS OF WORDS

# %%
import nltk
from collections import Counter
from nltk.tokenize import word_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
text='india is my country'
words=word_tokenize(text)
words=[word.lower() for word in words if word.isalnum()]
total_words=len(words)
unique_words=set(words)
word_freq=Counter(words)
longest_word=max(words,key=len)
shortest_word=min(words,key=len)
print('TOTAL_WORDS:', total_words)
print('UNIQUE_WORDS:', unique_words)
print('WORD_FREQ:', word_freq)
print ('LONGEST_WORD:', longest_word)
print ('SHORTEST_WORD:', shortest_word)
# Out:
# TOTAL_WORDS: 4
# UNIQUE_WORDS: {'india', 'my', 'country', 'is'}
# WORD_FREQ: Counter({'india': 1, 'is': 1, 'my': 1, 'country': 1})
# LONGEST_WORD: country
# SHORTEST_WORD: is

# %%
RANDOM WORD GENERATION

# %%
import random
import string
import nltk
from nltk.corpus import words
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
words_list=words.words()
def generate_random_word():
  return random.choice(words_list)
print("generating 8 words")
for _ in range(8):
    print(generate_random_word())
# Out:
# generating 8 words
# raglanite
# coruscate
# alabastrian
# Bucerotidae
# erotical
# predestinator
# submeter
# osteoperiostitis
